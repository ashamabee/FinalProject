# %%
import pandas as pd
from sqlalchemy import create_engine
import matplotlib.pyplot as plt

# %%
# Storing IMDB_movies.csv aquired from Data World.
imdb_file = "data/IMDb_movies.csv"
imdb_df = pd.read_csv(imdb_file)
imdb_df.head(5)
# Out:
#   imdb_title_id                                              title  \
# 0     tt0000574                        The Story of the Kelly Gang
# 1     tt0001892                                     Den sorte drøm
# 2     tt0002101                                          Cleopatra
# 3     tt0002130                                          L'Inferno
# 4     tt0002199  From the Manger to the Cross; or, Jesus of Naz...
#
#                                       original_title  year date_published  \
# 0                        The Story of the Kelly Gang  1906     12/26/1906
# 1                                     Den sorte drøm  1911      8/19/1911
# 2                                          Cleopatra  1912     11/13/1912
# 3                                          L'Inferno  1911       3/6/1911
# 4  From the Manger to the Cross; or, Jesus of Naz...  1912           1913
#
#                        genre  duration           country language  \
# 0    Biography, Crime, Drama        70         Australia      NaN
# 1                      Drama        53  Germany, Denmark      NaN
# 2             Drama, History       100               USA  English
# 3  Adventure, Drama, Fantasy        68             Italy  Italian
# 4           Biography, Drama        60               USA  English
#
#                               director  ...  \
# 0                         Charles Tait  ...
# 1                            Urban Gad  ...
# 2                   Charles L. Gaskill  ...
# 3  Francesco Bertolini, Adolfo Padovan  ...
# 4                        Sidney Olcott  ...
#
#                                               actors  \
# 0  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 1  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 2  Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 3  Salvatore Papa, Arturo Pirovano, Giuseppe de L...
# 4  R. Henderson Bland, Percy Dyer, Gene Gauntier,...
#
#                                          description avg_vote votes    budget  \
# 0  True story of notorious Australian outlaw Ned ...      6.1   537   $2,250
# 1  Two men of high rank are both wooing the beaut...      5.9   171       NaN
# 2  The fabled queen of Egypt's affair with Roman ...      5.2   420  $45,000
# 3  Loosely adapted from Dante's Divine Comedy and...      7.0  2019       NaN
# 4  An account of the life of Jesus Christ, based ...      5.7   438       NaN
#
#    usa_gross_income worlwide_gross_income metascore reviews_from_users  \
# 0               NaN                   NaN       NaN                7.0
# 1               NaN                   NaN       NaN                4.0
# 2               NaN                   NaN       NaN               24.0
# 3               NaN                   NaN       NaN               28.0
# 4               NaN                   NaN       NaN               12.0
#
#    reviews_from_critics
# 0                   7.0
# 1                   2.0
# 2                   3.0
# 3                  14.0
# 4                   5.0
#
# [5 rows x 22 columns]

# %%
imdb_mov = ["imdb_title_id", "title", "year", "genre", "duration", "country", "director", "actors","description","avg_vote",
            "budget", "usa_gross_income", "worlwide_gross_income", "votes","reviews_from_users","reviews_from_critics"]
imdb_trnfmd = imdb_df[imdb_mov].copy()

# %%
# Rename the column headers
imdb_trnfmd = imdb_trnfmd.rename(columns={"imdb_title_id": "title_id",
                                                          "usa_gross_income": "gross_income_usa",
                                                          "worlwide_gross_income": "gross_income_global",
                                                          "reviews_from_users": "user_reviews",
                                                        "reviews_from_critics": "critics_reviews"})

# %%
# Clean the data by dropping duplicates

imdb_trnfmd.drop_duplicates("title_id", inplace=True)

# Filtering DF by keeping based on year 2000 and up, and Country = 'USA'
imdb_trnfmd = imdb_trnfmd.loc[imdb_trnfmd["year"] >= 2000, :]
imdb_trnfmd = imdb_trnfmd.loc[imdb_trnfmd["country"] == "USA", :]

# Copy of existing dataframe
imdb_movies_df = imdb_trnfmd.copy()

#Dropping NaN Values from whole dataframe

imdb_movies_df = imdb_movies_df.dropna()

# %%
# This is commented because we ran this block of code successfully
# Removing $, EUR, AD currency indicators and turn columns into Integer from Object.
imdb_movies_df[imdb_movies_df.columns[10:12]] = imdb_movies_df[imdb_movies_df.columns[10:12]].replace('[$,EUR,AD,AUD,ER]', '', regex=True).astype(int)

# %%
#COLUMN 12 TO REMOVE $ AND OTHER POSSIBLE CURRENCY SYMBOLS.
imdb_movies_df[imdb_movies_df.columns[12]] = imdb_movies_df[imdb_movies_df.columns[12]].replace('[$,EUR,AD,AUD,ER]', '', regex=True).astype(float)

# %%
# Droping the country column
imdb_movies_df.drop(columns=['country'],inplace = True)
# Droping gross income global column
#imdb_movies_df.drop(columns=['gross_income_global'],inplace = True)

# %%
#imdb_movies_df.sort_values(by=['year'])
imdb_movies_df.sort_values(by=['title', 'year'], ascending= True, inplace = True )
# Resetting index
imdb_movies_df.reset_index()
# Out:
#       index   title_id                    title  year  \
# 0     51106  tt1022603     (500) Days of Summer  2009
# 1     52960  tt1179933      10 Cloverfield Lane  2016
# 2     68755  tt3453052    10 Days in a Madhouse  2015
# 3     66230  tt2789014        100 Acres of Hell  2019
# 4     42096  tt0360323              10th & Wolf  2006
# ...     ...        ...                      ...   ...
# 2475  43211  tt0383060                     Zoom  2006
# 2476  66761  tt2948356                 Zootopia  2016
# 2477  45106  tt0429277                Zyzzyx Rd  2006
# 2478  39650  tt0295701                      xXx  2002
# 2479  41083  tt0329774  xXx: State of the Union  2005
#
#                              genre  duration                  director  \
# 0           Comedy, Drama, Romance        95                 Marc Webb
# 1           Drama, Horror, Mystery       103          Dan Trachtenberg
# 2                            Drama       111             Timothy Hines
# 3                   Action, Horror        85           Hank Leigh Hump
# 4           Crime, Drama, Thriller       107             Bobby Moresco
# ...                            ...       ...                       ...
# 2475     Action, Adventure, Comedy        83              Peter Hewitt
# 2476  Animation, Adventure, Comedy       108  Byron Howard, Rich Moore
# 2477        Crime, Drama, Thriller        90               John Penney
# 2478   Action, Adventure, Thriller       124                 Rob Cohen
# 2479      Action, Adventure, Crime       101              Lee Tamahori
#
#                                                  actors  \
# 0     Joseph Gordon-Levitt, Zooey Deschanel, Geoffre...
# 1     John Goodman, Mary Elizabeth Winstead, John Ga...
# 2     Caroline Barry, Christopher Lambert, Kelly LeB...
# 3     Gene Snisky, Jeff Swanton, Jim Roof, Ernest O'...
# 4     James Marsden, Giovanni Ribisi, Brad Renfro, P...
# ...                                                 ...
# 2475  Tim Allen, Courteney Cox, Chevy Chase, Spencer...
# 2476  Ginnifer Goodwin, Jason Bateman, Idris Elba, J...
# 2477  Leo Grillo, Katherine Heigl, Tom Sizemore, Ric...
# 2478  Vin Diesel, Asia Argento, Marton Csokas, Samue...
# 2479  Willem Dafoe, Samuel L. Jackson, Ice Cube, Sco...
#
#                                             description  avg_vote     budget  \
# 0     An offbeat romantic comedy about a woman who d...       7.7    7500000
# 1     After getting in a car accident, a woman is he...       7.2   15000000
# 2     In 1887, at age 23, reporter Nellie Bly, worki...       6.7     120000
# 3     When ex pro wrestler Buck Severs travels to an...       2.9      65000
# 4     A former street tough returns to his Philadelp...       6.3    8000000
# ...                                                 ...       ...        ...
# 2475  Former superhero Jack is called back to work t...       4.3   35000000
# 2476  In a city of anthropomorphic animals, a rookie...       8.0  150000000
# 2477  The family man accountant Grant travels to Las...       4.0    2000000
# 2478  An extreme sports athlete, Xander Cage, is rec...       5.9   70000000
# 2479  Darius Stone, a new agent in the xXx program, ...       4.4   60000000
#
#       gross_income_usa  gross_income_global   votes  user_reviews  \
# 0             32391374         6.072273e+07  448799         563.0
# 1             72082998         1.102170e+08  268631         700.0
# 2                14616         1.461600e+04    1152          26.0
# 3                 5152         5.152000e+03     143          17.0
# 4                54702         1.434510e+05    5938          34.0
# ...                ...                  ...     ...           ...
# 2475          11989328         1.250619e+07   17598         119.0
# 2476         341268248         1.023784e+09  396148         642.0
# 2477                30         3.000000e+01     930          11.0
# 2478         142109382         2.774484e+08  168051         739.0
# 2479          26873932         7.102269e+07   64761         228.0
#
#       critics_reviews
# 0               349.0
# 1               514.0
# 2                 2.0
# 3                 9.0
# 4                24.0
# ...               ...
# 2475             61.0
# 2476            474.0
# 2477              1.0
# 2478            188.0
# 2479             62.0
#
# [2480 rows x 16 columns]

# %%
# keeping only first string of genre
imdb_movies_df["genre"] = imdb_movies_df.genre.str.split(",").str.get(0)

# %%
# Creating New Calculated column
imdb_movies_df["profit"] = imdb_movies_df["gross_income_global"] - imdb_movies_df["budget"]

# %%
imdb_movies_df.dtypes
# Out:
# title_id                object
# title                   object
# year                     int64
# genre                   object
# duration                 int64
# director                object
# actors                  object
# description             object
# avg_vote               float64
# budget                   int32
# gross_income_usa         int32
# gross_income_global    float64
# votes                    int64
# user_reviews           float64
# critics_reviews        float64
# profit                 float64
# dtype: object

# %%
# Displaying clean final data frame
imdb_movies_df.head()
# Out:
#         title_id                  title  year   genre  duration  \
# 51106  tt1022603   (500) Days of Summer  2009  Comedy        95
# 52960  tt1179933    10 Cloverfield Lane  2016   Drama       103
# 68755  tt3453052  10 Days in a Madhouse  2015   Drama       111
# 66230  tt2789014      100 Acres of Hell  2019  Action        85
# 42096  tt0360323            10th & Wolf  2006   Crime       107
#
#                director                                             actors  \
# 51106         Marc Webb  Joseph Gordon-Levitt, Zooey Deschanel, Geoffre...
# 52960  Dan Trachtenberg  John Goodman, Mary Elizabeth Winstead, John Ga...
# 68755     Timothy Hines  Caroline Barry, Christopher Lambert, Kelly LeB...
# 66230   Hank Leigh Hump  Gene Snisky, Jeff Swanton, Jim Roof, Ernest O'...
# 42096     Bobby Moresco  James Marsden, Giovanni Ribisi, Brad Renfro, P...
#
#                                              description  avg_vote    budget  \
# 51106  An offbeat romantic comedy about a woman who d...       7.7   7500000
# 52960  After getting in a car accident, a woman is he...       7.2  15000000
# 68755  In 1887, at age 23, reporter Nellie Bly, worki...       6.7    120000
# 66230  When ex pro wrestler Buck Severs travels to an...       2.9     65000
# 42096  A former street tough returns to his Philadelp...       6.3   8000000
#
#        gross_income_usa  gross_income_global   votes  user_reviews  \
# 51106          32391374           60722734.0  448799         563.0
# 52960          72082998          110216998.0  268631         700.0
# 68755             14616              14616.0    1152          26.0
# 66230              5152               5152.0     143          17.0
# 42096             54702             143451.0    5938          34.0
#
#        critics_reviews      profit
# 51106            349.0  53222734.0
# 52960            514.0  95216998.0
# 68755              2.0   -105384.0
# 66230              9.0    -59848.0
# 42096             24.0  -7856549.0

# %%
# machine learnign codes

# %%
 imdb_machine_df = imdb_movies_df [["profit", "duration", "avg_vote", "votes", "critics_reviews", "genre"]]

# %%
X = imdb_machine_df[["duration", "avg_vote", "votes", "critics_reviews", "genre"]]

# %%
y = imdb_machine_df["profit"].values.reshape(-1, 1)

# %%
print(X.shape,y.shape)
# Out:
# (2480, 5) (2480, 1)

# %%
data = X.copy()

# %%
data_encode = pd.get_dummies(data["genre"])

# %%
data_encode.head()
# Out:
#        Action  Adventure  Animation  Biography  Comedy  Crime  Drama  Family  \
# 51106       0          0          0          0       1      0      0       0
# 52960       0          0          0          0       0      0      1       0
# 68755       0          0          0          0       0      0      1       0
# 66230       1          0          0          0       0      0      0       0
# 42096       0          0          0          0       0      1      0       0
#
#        Fantasy  Horror  Music  Musical  Mystery  Romance  Sci-Fi  Sport  \
# 51106        0       0      0        0        0        0       0      0
# 52960        0       0      0        0        0        0       0      0
# 68755        0       0      0        0        0        0       0      0
# 66230        0       0      0        0        0        0       0      0
# 42096        0       0      0        0        0        0       0      0
#
#        Thriller  Western
# 51106         0        0
# 52960         0        0
# 68755         0        0
# 66230         0        0
# 42096         0        0

# %%
X[data_encode.columns] = data_encode
del X["genre"]
X
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'genre'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-145-0b7e74e53c4f> in <module>
#       1 X[data_encode.columns] = data_encode
# ----> 2 del X["genre"]
#       3 X
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __delitem__(self, key)
#    3757             # there was no match, this call should raise the appropriate
#    3758             # exception:
# -> 3759             self._data.delete(key)
#    3760
#    3761         # delete from the caches
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in delete(self, item)
#    1000         Delete selected item (items if non-unique) in-place.
#    1001         """
# -> 1002         indexer = self.items.get_loc(item)
#    1003
#    1004         is_deleted = np.zeros(self.shape[0], dtype=np.bool_)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'genre'

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)

# %%
X_train.head()
# Out:
#        duration  avg_vote   votes  critics_reviews  Action  Adventure  \
# 71388       104       7.6   23684             35.0       0          0
# 59973       140       7.3  231149            431.0       0          0
# 80004       110       4.7    4663             36.0       0          0
# 57557       101       5.4   31609            295.0       0          0
# 70858        87       6.4    1393              5.0       0          0
#
#        Animation  Biography  Comedy  Crime  ...  Fantasy  Horror  Music  \
# 71388          0          0       1      0  ...        0       0      0
# 59973          0          0       0      1  ...        0       0      0
# 80004          0          0       1      0  ...        0       0      0
# 57557          0          0       0      0  ...        0       0      0
# 70858          0          0       0      0  ...        0       1      0
#
#        Musical  Mystery  Romance  Sci-Fi  Sport  Thriller  Western
# 71388        0        0        0       0      0         0        0
# 59973        0        0        0       0      0         0        0
# 80004        0        0        0       0      0         0        0
# 57557        0        0        0       0      0         0        0
# 70858        0        0        0       0      0         0        0
#
# [5 rows x 22 columns]

# %%
from sklearn.preprocessing import StandardScaler 
X_scaler = StandardScaler().fit(X_train)

# %%
y_scaler = StandardScaler().fit(y_train)

# %%
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
# y_train_scaled = y_scaler.transform(y_train)
# y_test_scaled = y_scaler.transform(y_test)

y_train_scaled = y_train
y_test_scaled = y_test

# %%
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
model = LinearRegression()
model.fit(X_train_scaled, y_train_scaled)
plt.scatter(model.predict(X_train_scaled), model.predict(X_train_scaled) - y_train_scaled, c="blue", label="Training Data")
plt.scatter(model.predict(X_test_scaled), model.predict(X_test_scaled) - y_test_scaled, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y_test_scaled.min(), xmax=y_test_scaled.max())
plt.title("Residual Plot")
plt.show()

# %%
importance = model.coef_
for i,v in enumerate(importance[0]):
    print("feature: %0d,score: %.5f" % (i,v))
# Out:
# feature: 0,score: 16753548.02970
# feature: 1,score: -19902851.34131
# feature: 2,score: 91492537.03557
# feature: 3,score: 29648779.35125
# feature: 4,score: 5486381.17286
# feature: 5,score: 1805983.46006
# feature: 6,score: 39686279.06555
# feature: 7,score: -9170892.91492
# feature: 8,score: -4787753.46192
# feature: 9,score: -12577337.10714
# feature: 10,score: -7415164.70959
# feature: 11,score: 13868316.72040
# feature: 12,score: -1330077.95521
# feature: 13,score: -3105715.67054
# feature: 14,score: 187282.08905
# feature: 15,score: 510046.96933
# feature: 16,score: -12146385.41387
# feature: 17,score: -488741.57785
# feature: 18,score: -4922779.17646
# feature: 19,score: 170667.93610
# feature: 20,score: 274118.08704
# feature: 21,score: -240308.04289

# %%
plt.bar([x for x in range(len(importance[0]))], importance[0])
plt.show()

# %%
from sklearn.metrics import mean_squared_error

predictions = model.predict(X_test_scaled)
MSE = mean_squared_error(y_test_scaled, predictions)
r2 = model.score(X_test_scaled, y_test_scaled)

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 1.4330136949070446e+16, R2: 0.4138025792050899

# %%
#y_test_scaled

# %%
y_list = [a[0] for a in y_test_scaled]
p_list = [a[0] for a in predictions]
pd.DataFrame({"predictions":p_list, "actuals": y_list}).round(0)
# Out:
#      predictions      actuals
# 0     40341857.0    3960481.0
# 1    -34158729.0  -12286045.0
# 2     75159461.0   67648706.0
# 3      4754047.0   35742992.0
# 4     28607471.0   12886719.0
# ..           ...          ...
# 615  123689307.0  127725639.0
# 616  -19582080.0    1661020.0
# 617  -11022605.0   -1811610.0
# 618   50438773.0  132874864.0
# 619   28122194.0  113133739.0
#
# [620 rows x 2 columns]

# %%
# Stop......Please read carefully.

# %%
# Please Create New Database in pgAdmin (final_project_db) and " table (imdb_movies)

# %%
# Connecting to local database 
ETL_connection_string = "admin1:12345@localhost:5432/final_project_db"
engine = create_engine(f'postgresql://{ETL_connection_string}')

# %%
# Pulling tables from database
engine.table_names()
# Out:
# ['imdb_movies']

# %%
# Below code worked and loaded successfully into pgAdmin Database table. 
imdb_movies_df.to_sql(name='imdb_movies', con=engine, if_exists='append', index=False)

# %%
#Confirm data has been added by querying the customer_name table
pd.read_sql_query('select * from imdb_movies', con=engine).head()
# Out:
#     title_id                  title  year   genre  duration          director  \
# 0  tt1022603   (500) Days of Summer  2009  Comedy        95         Marc Webb
# 1  tt1179933    10 Cloverfield Lane  2016   Drama       103  Dan Trachtenberg
# 2  tt3453052  10 Days in a Madhouse  2015   Drama       111     Timothy Hines
# 3  tt2789014      100 Acres of Hell  2019  Action        85   Hank Leigh Hump
# 4  tt0360323            10th & Wolf  2006   Crime       107     Bobby Moresco
#
#                                               actors  \
# 0  Joseph Gordon-Levitt, Zooey Deschanel, Geoffre...
# 1  John Goodman, Mary Elizabeth Winstead, John Ga...
# 2  Caroline Barry, Christopher Lambert, Kelly LeB...
# 3  Gene Snisky, Jeff Swanton, Jim Roof, Ernest O'...
# 4  James Marsden, Giovanni Ribisi, Brad Renfro, P...
#
#                                          description  avg_vote    budget  \
# 0  An offbeat romantic comedy about a woman who d...       7.7   7500000
# 1  After getting in a car accident, a woman is he...       7.2  15000000
# 2  In 1887, at age 23, reporter Nellie Bly, worki...       6.7    120000
# 3  When ex pro wrestler Buck Severs travels to an...       2.9     65000
# 4  A former street tough returns to his Philadelp...       6.3   8000000
#
#    gross_income_usa  gross_income_global   votes  user_reviews  \
# 0          32391374           60722734.0  448799         563.0
# 1          72082998          110216998.0  268631         700.0
# 2             14616              14616.0    1152          26.0
# 3              5152               5152.0     143          17.0
# 4             54702             143451.0    5938          34.0
#
#    critics_reviews      profit
# 0            349.0  53222734.0
# 1            514.0  95216998.0
# 2              2.0   -105384.0
# 3              9.0    -59848.0
# 4             24.0  -7856549.0

# %%
imdb_movies_df.to_csv("data/moviesCSV_for_Tableau.csv")

# %%
# Possible Machine Learning coding below using clean imdb_movies_df data frame.
# Last Modified 12/14/20 
# added Global income and profit columns and loaded into prosgres SQL.

# %%
# Import dependencies
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
model = LinearRegression()
X = imdb_movies_df["critics_reviews"].values.reshape(-1,1)
y = imdb_movies_df["profit"].values.reshape(-1,1)

# %%
import matplotlib.pyplot as plt
plt.scatter(X, y)
plt.xlabel("critics_reviews")
plt.ylabel("profit")
# Out:
# Text(0, 0.5, 'profit')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=50)

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Calculate the mean_squared_error and the r-squared value
# for the testing data
from sklearn.metrics import mean_squared_error, r2_score

# Use our model to make predictions
predicted = model.predict(X_test)

# Score the predictions with mse and r2
mse = mean_squared_error(y_test, predicted)
r2 = r2_score(y_test, predicted)

print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R2 ): {r2}")

### END SOLUTION
# Out:
# Mean Squared Error (MSE): 1.7159008471931722e+16
# R-squared (R2 ): 0.23241942798665438

# %%
model.score(X_test, y_test)
# Out:
# 0.335563206837448
